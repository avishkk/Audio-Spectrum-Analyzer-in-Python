# %%
import pyaudio
import os
import struct
import numpy as np
import matplotlib.pyplot as plt
from scipy.fftpack import fft
import time
from tkinter import TclError
import serial
import wave
from scipy.signal import butter, filtfilt

# to display in separate Tk window
# %matplotlib tk

# constants
CHUNK = 1024*4  # samples per frame
FORMAT = pyaudio.paInt16  # audio format (bytes per sample)
CHANNELS = 1  # single channel for microphone
RATE = 44100  # samples per second

wav_file = wave.open(r"C:\Users\rajka\Downloads\My Song 7.wav", 'rb')

# Set up serial communication with Arduino
arduino = serial.Serial('COM4', 9600)
time.sleep(2)  # Wait for Arduino to initialize

# pyaudio class instance
p = pyaudio.PyAudio()

# stream object to get data from microphone
stream = p.open(
    format=p.get_format_from_width(wav_file.getsampwidth()),
    channels=wav_file.getnchannels(),
    rate=wav_file.getframerate(),
    input=False,
    output=True,
    frames_per_buffer=CHUNK
)

# create matplotlib figure and axes
fig, ax2 = plt.subplots(figsize=(15, 7))

# Define the frequency bins for the bar plot
# freq_bins = [40,50,60,100,150,200,250,300,400,450,600,800,1000]
freq_bins=[50,300,500]

# Create the x-axis labels for the bar plot
labels = [str(freq) for freq in freq_bins]

# Create the bar plot
bar_fft = ax2.bar(labels[:-1], np.zeros(len(labels) - 1))

# format spectrum axes
ax2.set_ylim(0, 1)

print('stream started')
chosen_frequencies = [50,300]

# for measuring frame rate
frame_count = 0
start_time = time.time()

# Read the audio data from the .wav file
data = wav_file.readframes(CHUNK)

while len(data) > 0:

    # convert data to integers, make np array, then offset it by 128
    data_int = np.array(struct.unpack(f"{2 * CHUNK}h", data), dtype=np.int16) + 128

    # compute FFT
    yf = fft(data_int)

    # Update the bar heights with the frequency values
    # for i in range(len(freq_bins) -1):
    #     # start_index = np.abs(np.fft.fftfreq(CHUNK, 1/RATE) - freq_bins[i]).argmin()
    #     # end_index = np.abs(np.fft.fftfreq(CHUNK, 1/RATE) - freq_bins[i + 1]).argmin()
    #     index = np.abs(np.fft.fftfreq(CHUNK, 1/RATE) - freq).argmin()
    #     value = np.abs(yf[index]) / (CHUNK*128)
    #     bar_fft[i].set_height(value / (CHUNK*128))
    # Update the bar heights with the frequency values
    for i in range(len(freq_bins) - 1):
        start_index = np.abs(np.fft.fftfreq(CHUNK, 1 / RATE) - freq_bins[i]).argmin()
        end_index = np.abs(np.fft.fftfreq(CHUNK, 1 / RATE) - freq_bins[i + 1]).argmin()
        bar_fft[i].set_height(np.abs(yf[start_index:end_index]).mean() / (CHUNK * 128))


    stream.write(data)

    # Send maximum frequencies and values to Arduino
    for freq in chosen_frequencies:
        index = np.abs(np.fft.fftfreq(CHUNK, 1/RATE) - freq).argmin()
        value = np.abs(yf[index]) / (CHUNK*128)
        print(f"Frequency: {freq} Hz, Value: {value}")
        message = f"{freq}:{value}\n".encode()  # Encode message as bytes
        arduino.write(message)

    try:
        fig.canvas.draw()
        fig.canvas.flush_events()
        frame_count += 1

    except TclError:
        # calculate average frame rate
        frame_rate = frame_count / (time.time() - start_time)

        print('stream stopped')
        print('average frame rate = {:.0f} FPS'.format(frame_rate))
        break

    # Read the next chunk of audio data from the .wav file
    data = wav_file.readframes(CHUNK)

print('Playback finished')
# Out:
# stream started
# Frequency: 50 Hz, Value: 93.9944791958704
# Frequency: 300 Hz, Value: 4.5168360439544335
# Frequency: 50 Hz, Value: 48.69796313984328
# Frequency: 300 Hz, Value: 0.5588605378066458
# Frequency: 50 Hz, Value: 13.823457434649518
# Frequency: 300 Hz, Value: 0.23694053170845333
# Frequency: 50 Hz, Value: 4.255466285115078
# Frequency: 300 Hz, Value: 0.11935266198190868
# Frequency: 50 Hz, Value: 1.2614682227638563
# Frequency: 300 Hz, Value: 0.04028052998407135
# Frequency: 50 Hz, Value: 0.2752758367737142
# Frequency: 300 Hz, Value: 0.00819387020446595
# Frequency: 50 Hz, Value: 0.63064947728024
# Frequency: 300 Hz, Value: 10.489149302492853
# Frequency: 50 Hz, Value: 0.05279987947303432
# Frequency: 300 Hz, Value: 0.0009675638491306184
# Frequency: 50 Hz, Value: 0.0017282808872078146
# Frequency: 300 Hz, Value: 0.0017612961515894314
# Frequency: 50 Hz, Value: 0.0036311039875618445
# Frequency: 300 Hz, Value: 0.0006884064375912199
# Frequency: 50 Hz, Value: 0.002851082019380509
# Frequency: 300 Hz, Value: 0.0006642469027032234
# Frequency: 50 Hz, Value: 4.071323272004221
# Frequency: 300 Hz, Value: 8.82355491191437
# Frequency: 50 Hz, Value: 118.14552296861282
# Frequency: 300 Hz, Value: 5.01388270643821
# Frequency: 50 Hz, Value: 36.872834942221886
# Frequency: 300 Hz, Value: 0.9876280898406827
# Frequency: 50 Hz, Value: 10.633245229012886
# Frequency: 300 Hz, Value: 0.34666218330565696
# Frequency: 50 Hz, Value: 3.0488177792839415
# Frequency: 300 Hz, Value: 0.0873932925326318
# Frequency: 50 Hz, Value: 0.8290238314361805
# Frequency: 300 Hz, Value: 0.013791126216873438
# Frequency: 50 Hz, Value: 0.5619550889762623
# Frequency: 300 Hz, Value: 11.544818896922202
# Frequency: 50 Hz, Value: 0.03986959854523778
# Frequency: 300 Hz, Value: 1.9786473355493501
# Frequency: 50 Hz, Value: 0.014864189707943886
# Frequency: 300 Hz, Value: 0.038463960210775576
# Frequency: 50 Hz, Value: 0.001976535357120895
# Frequency: 300 Hz, Value: 0.003590080697658137
# Frequency: 50 Hz, Value: 0.0020275251410682227
# Frequency: 300 Hz, Value: 0.0003964109325045318
# Frequency: 50 Hz, Value: 0.0024370678619158896
# Frequency: 300 Hz, Value: 0.0003159272367690184
# Frequency: 50 Hz, Value: 36.72056488997582
# Frequency: 300 Hz, Value: 3.8876300513358277
# Frequency: 50 Hz, Value: 100.42827005886777
# Frequency: 300 Hz, Value: 0.27550406742313327
# Frequency: 50 Hz, Value: 26.014632540150384
# Frequency: 300 Hz, Value: 0.7767476606173306
# Frequency: 50 Hz, Value: 7.184910901267313
# Frequency: 300 Hz, Value: 0.14096885712285012
# Frequency: 50 Hz, Value: 2.1364251113606314
# Frequency: 300 Hz, Value: 0.010863360476121258
# Frequency: 50 Hz, Value: 0.6063340824412944
# Frequency: 300 Hz, Value: 0.011061680697540991
# Frequency: 50 Hz, Value: 0.4881475863367393
# Frequency: 300 Hz, Value: 10.600700006353042
# Frequency: 50 Hz, Value: 0.10877180129539477
# Frequency: 300 Hz, Value: 0.30101360699608326
# Frequency: 50 Hz, Value: 0.01979199182090874
# Frequency: 300 Hz, Value: 0.0028222616844155953
# Frequency: 50 Hz, Value: 0.0024318281237997196
# Frequency: 300 Hz, Value: 0.0005717630623785128
# Frequency: 50 Hz, Value: 0.0011913153681052417
# Frequency: 300 Hz, Value: 0.00036228887093879385
# Frequency: 50 Hz, Value: 0.0009607256527791359
# Frequency: 300 Hz, Value: 0.0003101106172606941
# Frequency: 50 Hz, Value: 66.16313832057769
# Frequency: 300 Hz, Value: 4.9166381735987255
# Frequency: 50 Hz, Value: 72.11730375022078
# Frequency: 300 Hz, Value: 1.5556894002699984
# Frequency: 50 Hz, Value: 17.902599470014554
# Frequency: 300 Hz, Value: 0.10535060299892256
# Frequency: 50 Hz, Value: 5.424680515286283
# Frequency: 300 Hz, Value: 0.08637431163595095
# Frequency: 50 Hz, Value: 1.6984281064907896
# Frequency: 300 Hz, Value: 0.046983710723607096
# Frequency: 50 Hz, Value: 0.42367156479237783
# Frequency: 300 Hz, Value: 0.013621530283557105
# Frequency: 50 Hz, Value: 0.580293133093211
# Frequency: 300 Hz, Value: 10.561270298713001
# Frequency: 50 Hz, Value: 0.023352224635960286
# Frequency: 300 Hz, Value: 0.08616198566037317
# Frequency: 50 Hz, Value: 0.0032934631608799204
# Frequency: 300 Hz, Value: 0.005605871459620552
# Frequency: 50 Hz, Value: 0.004427966422265652
# Frequency: 300 Hz, Value: 0.001104731336858796
# Frequency: 50 Hz, Value: 0.0025658466627481854
# Frequency: 300 Hz, Value: 0.00042215740451560373
# Frequency: 50 Hz, Value: 0.0004230280828131481
# Frequency: 300 Hz, Value: 8.976041170582835e-05
# Frequency: 50 Hz, Value: 94.4601685113868
# Frequency: 300 Hz, Value: 4.735935911866478
# Frequency: 50 Hz, Value: 48.443526506624096
# Frequency: 300 Hz, Value: 0.43075527629933574
# Frequency: 50 Hz, Value: 14.14999816297724
# Frequency: 300 Hz, Value: 0.39621337556561204
# Frequency: 50 Hz, Value: 4.194770940456222
# Frequency: 300 Hz, Value: 0.13117286343189527
# Frequency: 50 Hz, Value: 1.1845152349549475
# Frequency: 300 Hz, Value: 0.03250535702185761
# Frequency: 50 Hz, Value: 0.2567665227994402
# Frequency: 300 Hz, Value: 0.003939924899244261
# Frequency: 50 Hz, Value: 0.5947839442625603
# Frequency: 300 Hz, Value: 10.500019855194285
# Frequency: 50 Hz, Value: 0.012601324278403655
# Frequency: 300 Hz, Value: 0.027869439597004112
# Frequency: 50 Hz, Value: 0.0026062070142892925
# Frequency: 300 Hz, Value: 0.001746254754531985
# Frequency: 50 Hz, Value: 0.003894742977460691
# Frequency: 300 Hz, Value: 0.0002592851528551968
# Frequency: 50 Hz, Value: 0.0032225034211285724
# Frequency: 300 Hz, Value: 0.0007636338469894882
# Frequency: 50 Hz, Value: 9.713442657634953
# Frequency: 300 Hz, Value: 5.541672337651543
# Frequency: 50 Hz, Value: 126.07156893293599
# Frequency: 300 Hz, Value: 1.7240923044644916
# Frequency: 50 Hz, Value: 36.29652096366731
# Frequency: 300 Hz, Value: 1.1656625418495237
# Frequency: 50 Hz, Value: 10.03775753682261
# Frequency: 300 Hz, Value: 0.2978715374266317
# Frequency: 50 Hz, Value: 2.8522381631387543
# Frequency: 300 Hz, Value: 0.05117857604241563
# Frequency: 50 Hz, Value: 0.8106853904470087
# Frequency: 300 Hz, Value: 0.005169409610633286
# Frequency: 50 Hz, Value: 0.301795957846741
# Frequency: 300 Hz, Value: 11.862273971509882
# Frequency: 50 Hz, Value: 0.2562855063267188
# Frequency: 300 Hz, Value: 2.007504328382554
# Frequency: 50 Hz, Value: 0.010286816675286158
# Frequency: 300 Hz, Value: 0.012155109994159991
# Frequency: 50 Hz, Value: 0.0018616649019496054
# Frequency: 300 Hz, Value: 0.0034482747987054966
# Frequency: 50 Hz, Value: 0.0018271698783017417
# Frequency: 300 Hz, Value: 0.000885581827748035
# Frequency: 50 Hz, Value: 0.0019208998156122388
# Frequency: 300 Hz, Value: 0.0003560539509725595
# Frequency: 50 Hz, Value: 36.93757913190741
# Frequency: 300 Hz, Value: 4.389178099705578
# Frequency: 50 Hz, Value: 100.40050067224536
# Frequency: 300 Hz, Value: 0.8813817439701808
# Frequency: 50 Hz, Value: 24.254963005512806
# Frequency: 300 Hz, Value: 0.4505864751772583
# Frequency: 50 Hz, Value: 6.95565701501739
# Frequency: 300 Hz, Value: 0.04205241502243743
# Frequency: 50 Hz, Value: 2.174973537553852
# Frequency: 300 Hz, Value: 0.03779764010519728
# Frequency: 50 Hz, Value: 0.6127301075104451
# Frequency: 300 Hz, Value: 0.01801838135331703
# Frequency: 50 Hz, Value: 0.5970387545456025
# Frequency: 300 Hz, Value: 10.52769261319226
# Frequency: 50 Hz, Value: 0.13107363175541314
# Frequency: 300 Hz, Value: 0.1517574373533373
# Frequency: 50 Hz, Value: 0.004641084924658017
# Frequency: 300 Hz, Value: 0.010854958349502942
# Frequency: 50 Hz, Value: 0.0027191534686866856
# Frequency: 300 Hz, Value: 0.0002995956715771662
# Frequency: 50 Hz, Value: 0.0008954013096770962
# Frequency: 300 Hz, Value: 0.00026020912372595875
# Frequency: 50 Hz, Value: 0.001007228078167965
# Frequency: 300 Hz, Value: 0.00021397217605270672
# Frequency: 50 Hz, Value: 70.5436137006979
# Frequency: 300 Hz, Value: 4.57703337205697
# Frequency: 50 Hz, Value: 67.97858126579952
# Frequency: 300 Hz, Value: 1.0896832458853594
# Frequency: 50 Hz, Value: 18.225657924387008
# Frequency: 300 Hz, Value: 0.3203499195075197
# Frequency: 50 Hz, Value: 5.543776726264431
# Frequency: 300 Hz, Value: 0.1567532194973994
# Frequency: 50 Hz, Value: 1.6624482614881877
# Frequency: 300 Hz, Value: 0.05196146120500927
# Frequency: 50 Hz, Value: 0.39349039475494824
# Frequency: 300 Hz, Value: 0.012001488726460565
# Frequency: 50 Hz, Value: 0.5544502451334564
# Frequency: 300 Hz, Value: 10.50931881958872
# Frequency: 50 Hz, Value: 0.044845996040849004
# Frequency: 300 Hz, Value: 0.10638207619194152
# Frequency: 50 Hz, Value: 0.005517405300983852
# Frequency: 300 Hz, Value: 0.0038833459175818936
# Frequency: 50 Hz, Value: 0.004633519407516284
# Frequency: 300 Hz, Value: 0.0014436301275521026
# Frequency: 50 Hz, Value: 0.0025565741915150827
# Frequency: 300 Hz, Value: 0.0004579265123650302
# Frequency: 50 Hz, Value: 0.00028985180292163937
# Frequency: 300 Hz, Value: 0.00015425889879751395
# Frequency: 50 Hz, Value: 94.70760570918006
# Frequency: 300 Hz, Value: 3.920033695566566
# Frequency: 50 Hz, Value: 49.20848560809283
# Frequency: 300 Hz, Value: 1.0861098467808254
# Frequency: 50 Hz, Value: 13.925060653915056
# Frequency: 300 Hz, Value: 0.4571601885427559
# Frequency: 50 Hz, Value: 3.958620463695168
# Frequency: 300 Hz, Value: 0.11580602468443173
# Frequency: 50 Hz, Value: 1.1090080282493349
# Frequency: 300 Hz, Value: 0.01825138555585901
# Frequency: 50 Hz, Value: 0.25058103039033325
# Frequency: 300 Hz, Value: 0.0018693223803188197
# Frequency: 50 Hz, Value: 0.5824391932848708
# Frequency: 300 Hz, Value: 10.483236097040313
# Frequency: 50 Hz, Value: 0.01808696378578006
# Frequency: 300 Hz, Value: 0.021729971545888186
# Frequency: 50 Hz, Value: 0.002851918410222924
# Frequency: 300 Hz, Value: 0.001419789665274967
# Frequency: 50 Hz, Value: 0.0046289166752930214
# Frequency: 300 Hz, Value: 0.00039152449703660727
# Frequency: 50 Hz, Value: 0.0030511145305240103
# Frequency: 300 Hz, Value: 0.0005789557482892021
# Frequency: 50 Hz, Value: 6.526863513769185
# Frequency: 300 Hz, Value: 2.2411194898395506
# Frequency: 50 Hz, Value: 124.68135550388828
# Frequency: 300 Hz, Value: 1.4456203457425776
# Frequency: 50 Hz, Value: 34.18838166782609
# Frequency: 300 Hz, Value: 1.0056829437532477
# Frequency: 50 Hz, Value: 9.357044775778036
# Frequency: 300 Hz, Value: 0.17905507417398553
# Frequency: 50 Hz, Value: 2.773776580920827
# Frequency: 300 Hz, Value: 0.01429064807285818
# Frequency: 50 Hz, Value: 0.8261277535250031
# Frequency: 300 Hz, Value: 0.015022560538623407
# Frequency: 50 Hz, Value: 0.45787250521280837
# Frequency: 300 Hz, Value: 11.672562258461157
# Frequency: 50 Hz, Value: 0.08053991309945792
# Frequency: 300 Hz, Value: 1.677361907423937
# Frequency: 50 Hz, Value: 0.014848853061137333
# Frequency: 300 Hz, Value: 0.03283271487083326
# Frequency: 50 Hz, Value: 0.0024280690624215555
# Frequency: 300 Hz, Value: 0.00090227359977409
# Frequency: 50 Hz, Value: 0.0014389050121333274
# Frequency: 300 Hz, Value: 0.0005687910419958802
# Frequency: 50 Hz, Value: 0.0019042472266426883
# Frequency: 300 Hz, Value: 0.0004119165265947911
# Frequency: 50 Hz, Value: 37.00162479504715
# Frequency: 300 Hz, Value: 5.220771807485907
# Frequency: 50 Hz, Value: 98.68887013969096
# Frequency: 300 Hz, Value: 1.2589332893488352
# Frequency: 50 Hz, Value: 23.560142750251885
# Frequency: 300 Hz, Value: 0.1370059258669391
# Frequency: 50 Hz, Value: 7.075229185793456
# Frequency: 300 Hz, Value: 0.11684693904659399
# Frequency: 50 Hz, Value: 2.215624959554771
# Frequency: 300 Hz, Value: 0.06145612437996136
# Frequency: 50 Hz, Value: 0.5929861282071264
# Frequency: 300 Hz, Value: 0.018791331117571062
# Frequency: 50 Hz, Value: 0.5866203111177944
# Frequency: 300 Hz, Value: 10.411285622274546
# Frequency: 50 Hz, Value: 0.0648986132309086
# Frequency: 300 Hz, Value: 0.1329362953879189
# Frequency: 50 Hz, Value: 0.007161199551403881
# Frequency: 300 Hz, Value: 0.007702664409255875
# Frequency: 50 Hz, Value: 0.002487542400397089
# Frequency: 300 Hz, Value: 0.00033889630803556287
# Frequency: 50 Hz, Value: 0.001226717364492134
# Frequency: 300 Hz, Value: 0.0004012157225605117
# Frequency: 50 Hz, Value: 0.0009436316725239521
# Frequency: 300 Hz, Value: 0.00020886086017943945
# Frequency: 50 Hz, Value: 73.34420724737745
# Frequency: 300 Hz, Value: 4.77744090431005
# Frequency: 50 Hz, Value: 65.96092926893019
# Frequency: 300 Hz, Value: 0.41430603778117314
# Frequency: 50 Hz, Value: 18.610312616184867
# Frequency: 300 Hz, Value: 0.5285429262764048
# Frequency: 50 Hz, Value: 5.4565904047257385
# Frequency: 300 Hz, Value: 0.17049341790557274
# Frequency: 50 Hz, Value: 1.5632947651175166
# Frequency: 300 Hz, Value: 0.042598703446700345
# Frequency: 50 Hz, Value: 0.36666954870777874
# Frequency: 300 Hz, Value: 0.005455563773729948
# Frequency: 50 Hz, Value: 0.5088383135318604
# Frequency: 300 Hz, Value: 10.437099732888031
# Frequency: 50 Hz, Value: 0.08835714053952402
# Frequency: 300 Hz, Value: 0.1508606382937152
# Frequency: 50 Hz, Value: 0.0020595270368676355
# Frequency: 300 Hz, Value: 0.007393792956506776
# Frequency: 50 Hz, Value: 0.0045653552625635405
# Frequency: 300 Hz, Value: 0.0013765014709733174
# Frequency: 50 Hz, Value: 0.00285715071766014
# Frequency: 300 Hz, Value: 0.0005112185978323501
# Frequency: 50 Hz, Value: 0.00015674294995751814
# Frequency: 300 Hz, Value: 5.222827220908604e-05
# Frequency: 50 Hz, Value: 96.66303351274624
# Frequency: 300 Hz, Value: 5.4875951679650425
# Frequency: 50 Hz, Value: 48.66177766244955
# Frequency: 300 Hz, Value: 1.4277543767629781
# Frequency: 50 Hz, Value: 13.112421324133216
# Frequency: 300 Hz, Value: 0.3889595347127867
# Frequency: 50 Hz, Value: 3.698518405156546
# Frequency: 300 Hz, Value: 0.06485901381612631
# Frequency: 50 Hz, Value: 1.0845228494656982
# Frequency: 300 Hz, Value: 0.006813847004851812
# Frequency: 50 Hz, Value: 0.2536508724509397
# Frequency: 300 Hz, Value: 0.004319560643874121
# Frequency: 50 Hz, Value: 0.5754567671194223
# Frequency: 300 Hz, Value: 10.478031383701673
# Frequency: 50 Hz, Value: 0.022318827918389215
# Frequency: 300 Hz, Value: 0.02349731561131525
# Frequency: 50 Hz, Value: 0.003818327131118334
# Frequency: 300 Hz, Value: 0.003349209747627676
# Frequency: 50 Hz, Value: 0.0037967965550766147
# Frequency: 300 Hz, Value: 0.0011508786467652242
# Frequency: 50 Hz, Value: 0.003198508041657672
# Frequency: 300 Hz, Value: 0.0006111568402848038
# Frequency: 50 Hz, Value: 8.789146190904237
# Frequency: 300 Hz, Value: 6.459097803967301
# Frequency: 50 Hz, Value: 121.94385426682972
# Frequency: 300 Hz, Value: 1.4071183287397053
# Frequency: 50 Hz, Value: 31.924316307498394
# Frequency: 300 Hz, Value: 0.5847132224393928
# Frequency: 50 Hz, Value: 9.074924980018034
# Frequency: 300 Hz, Value: 0.05581237863421738
# Frequency: 50 Hz, Value: 2.8243079167359735
# Frequency: 300 Hz, Value: 0.05019890957300491
# Frequency: 50 Hz, Value: 0.8359275311851622
# Frequency: 300 Hz, Value: 0.024063797515484812
# Frequency: 50 Hz, Value: 0.239504557996062
# Frequency: 300 Hz, Value: 11.688351027806851
# Frequency: 50 Hz, Value: 0.45343694049853467
# Frequency: 300 Hz, Value: 1.4591480417542337
# Frequency: 50 Hz, Value: 0.010590650412090171
# Frequency: 300 Hz, Value: 0.011287555917635222
# Frequency: 50 Hz, Value: 0.005519725929711574
# Frequency: 300 Hz, Value: 0.006099916595625725
# Frequency: 50 Hz, Value: 0.0009444397808500517
# Frequency: 300 Hz, Value: 0.0008732705131001804
# Frequency: 50 Hz, Value: 0.002128053541227056
# Frequency: 300 Hz, Value: 0.0003746797971864002
# Frequency: 50 Hz, Value: 39.94260425733971
# Frequency: 300 Hz, Value: 3.8879306210309483
# Frequency: 50 Hz, Value: 94.76806537131601
# Frequency: 300 Hz, Value: 1.567217195389229
# Frequency: 50 Hz, Value: 24.002975610646395
# Frequency: 300 Hz, Value: 0.4294688979514729
# Frequency: 50 Hz, Value: 7.2257263985952545
# Frequency: 300 Hz, Value: 0.2055771170188904
# Frequency: 50 Hz, Value: 2.1715832591974515
# Frequency: 300 Hz, Value: 0.06760047094041004
# Frequency: 50 Hz, Value: 0.5521840084427708
# Frequency: 300 Hz, Value: 0.016396789242337804
# Frequency: 50 Hz, Value: 0.5819398334605081
# Frequency: 300 Hz, Value: 10.41544500471701
# Frequency: 50 Hz, Value: 0.07430500749658789
# Frequency: 300 Hz, Value: 0.13370730823465674
# Frequency: 50 Hz, Value: 0.01203509524351511
# Frequency: 300 Hz, Value: 0.009305938411781556
# Frequency: 50 Hz, Value: 0.0033571596946808395
# Frequency: 300 Hz, Value: 0.0005171618826559364
# Frequency: 50 Hz, Value: 0.0016208776645299722
# Frequency: 300 Hz, Value: 0.0003501865994326783
# Frequency: 50 Hz, Value: 0.000475960302758403
# Frequency: 300 Hz, Value: 0.00021497987232135273
# Frequency: 50 Hz, Value: 73.77987151578013
# Frequency: 300 Hz, Value: 4.2370209786764175
# Frequency: 50 Hz, Value: 66.25485390907188
# Frequency: 300 Hz, Value: 0.7793359952220812
# Frequency: 50 Hz, Value: 18.284050923884905
# Frequency: 300 Hz, Value: 0.6037358836001424
# Frequency: 50 Hz, Value: 5.148725222749265
# Frequency: 300 Hz, Value: 0.15251788548048603
# Frequency: 50 Hz, Value: 1.4661360323741557
# Frequency: 300 Hz, Value: 0.02394033595622726
# Frequency: 50 Hz, Value: 0.35911935989149296
# Frequency: 300 Hz, Value: 0.0026216455460188366
# Frequency: 50 Hz, Value: 0.6041288775947288
# Frequency: 300 Hz, Value: 10.503712819386532
# Frequency: 50 Hz, Value: 0.018880074904030698
# Frequency: 300 Hz, Value: 0.013820102545916504
# Frequency: 50 Hz, Value: 0.0032302841583669696
# Frequency: 300 Hz, Value: 0.0006890773258928324
# Frequency: 50 Hz, Value: 0.00399017662663444
# Frequency: 300 Hz, Value: 0.0011908401214403026
# Frequency: 50 Hz, Value: 0.0027840510888742895
# Frequency: 300 Hz, Value: 0.0006091348700229006
# Frequency: 50 Hz, Value: 0.00011022529585802683
# Frequency: 300 Hz, Value: 0.00010124990264334045
# Frequency: 50 Hz, Value: 100.06500873137398
# Frequency: 300 Hz, Value: 3.6730588926724184
# Frequency: 50 Hz, Value: 46.12673953788661
# Frequency: 300 Hz, Value: 1.3336244187528647
# Frequency: 50 Hz, Value: 12.233206430923534
# Frequency: 300 Hz, Value: 0.2296681423833698
# Frequency: 50 Hz, Value: 3.598446679593356
# Frequency: 300 Hz, Value: 0.018992898496073232
# Frequency: 50 Hz, Value: 1.1055521790598632
# Frequency: 300 Hz, Value: 0.02023893640046838
# Frequency: 50 Hz, Value: 0.25352432507671485
# Frequency: 300 Hz, Value: 0.00679305879606517
# Frequency: 50 Hz, Value: 0.6139235588223069
# Frequency: 300 Hz, Value: 10.543446052194467
# Frequency: 50 Hz, Value: 0.03722399107999925
# Frequency: 300 Hz, Value: 0.05854763078555827
# Frequency: 50 Hz, Value: 0.006567581788818357
# Frequency: 300 Hz, Value: 0.003962589412253433
# Frequency: 50 Hz, Value: 0.0034777518744789444
# Frequency: 300 Hz, Value: 0.000570862935539374
# Frequency: 50 Hz, Value: 0.003324931934430784
# Frequency: 300 Hz, Value: 0.00047103983206981846
# Frequency: 50 Hz, Value: 12.959018713497365
# Frequency: 300 Hz, Value: 3.7266886103431336
# Frequency: 50 Hz, Value: 121.67624794212777
# Frequency: 300 Hz, Value: 0.7176821718548746
# Frequency: 50 Hz, Value: 31.010677081501868
# Frequency: 300 Hz, Value: 0.17852079405493249
# Frequency: 50 Hz, Value: 9.239244665324046
# Frequency: 300 Hz, Value: 0.15834671851226478
# Frequency: 50 Hz, Value: 2.879383213576428
# Frequency: 300 Hz, Value: 0.07962858777416887
# Frequency: 50 Hz, Value: 0.8111759364042954
# Frequency: 300 Hz, Value: 0.0252663676486108
# Frequency: 50 Hz, Value: 0.6601459085354294
# Frequency: 300 Hz, Value: 11.657251950076834
# Frequency: 50 Hz, Value: 0.4118499765372925
# Frequency: 300 Hz, Value: 1.1936346758515273
# Frequency: 50 Hz, Value: 0.01988054729722147
# Frequency: 300 Hz, Value: 0.012386382366589089
# Frequency: 50 Hz, Value: 0.0014556133108695978
# Frequency: 300 Hz, Value: 0.0022189261817768453
# Frequency: 50 Hz, Value: 0.0010698447507500285
# Frequency: 300 Hz, Value: 0.0008884911708998032
# Frequency: 50 Hz, Value: 0.0018600276745565567
# Frequency: 300 Hz, Value: 0.0002672937214732937
# Frequency: 50 Hz, Value: 45.54646020964951
# Frequency: 300 Hz, Value: 5.747176115683226
# Frequency: 50 Hz, Value: 90.19237329563289
# Frequency: 300 Hz, Value: 1.316505719016948
# Frequency: 50 Hz, Value: 24.488900962692195
# Frequency: 300 Hz, Value: 0.6986578774729311
# Frequency: 50 Hz, Value: 7.107326612304137
# Frequency: 300 Hz, Value: 0.22312577718130178
# Frequency: 50 Hz, Value: 2.0441719082725753
# Frequency: 300 Hz, Value: 0.055721651218978006
# Frequency: 50 Hz, Value: 0.5156359444877849
# Frequency: 300 Hz, Value: 0.00752888599669378
# Frequency: 50 Hz, Value: 0.44811770410616225
# Frequency: 300 Hz, Value: 10.489858233714605
# Frequency: 50 Hz, Value: 0.13664123709546422
# Frequency: 300 Hz, Value: 0.09151388977690476
# Frequency: 50 Hz, Value: 0.010308087174656656
# Frequency: 300 Hz, Value: 0.02017377502842658
# Frequency: 50 Hz, Value: 0.0019390862165726253
# Frequency: 300 Hz, Value: 0.002060905688529546
# Frequency: 50 Hz, Value: 0.0022260136201959907
# Frequency: 300 Hz, Value: 0.00050075357103795
# Frequency: 50 Hz, Value: 0.00018680522098556956
# Frequency: 300 Hz, Value: 0.00026933307558022504
# Frequency: 50 Hz, Value: 73.99993000162563
# Frequency: 300 Hz, Value: 5.124708721710392
# Frequency: 50 Hz, Value: 66.23783128419808
# Frequency: 300 Hz, Value: 1.4512810908608118
# Frequency: 50 Hz, Value: 17.189054836273158
# Frequency: 300 Hz, Value: 0.5077901363041954
# Frequency: 50 Hz, Value: 4.808656040973049
# Frequency: 300 Hz, Value: 0.08328612101449848
# Frequency: 50 Hz, Value: 1.434065322177063
# Frequency: 300 Hz, Value: 0.008622908812638067
# Frequency: 50 Hz, Value: 0.3656814763140384
# Frequency: 300 Hz, Value: 0.007587481894744942
# Frequency: 50 Hz, Value: 0.5809047198739659
# Frequency: 300 Hz, Value: 10.51442693921207
# Frequency: 50 Hz, Value: 0.04664430042461962
# Frequency: 300 Hz, Value: 0.03582658638235911
# Frequency: 50 Hz, Value: 0.004602200617820679
# Frequency: 300 Hz, Value: 0.0018195455800757193
# Frequency: 50 Hz, Value: 0.004539485624607189
# Frequency: 300 Hz, Value: 0.0016301908799931345
# Frequency: 50 Hz, Value: 0.002958156788727058
# Frequency: 300 Hz, Value: 0.0007292675543065598
# Frequency: 50 Hz, Value: 0.00012235231322194116
# Frequency: 300 Hz, Value: 5.483371244694722e-05
# Frequency: 50 Hz, Value: 102.9624747079281
# Frequency: 300 Hz, Value: 5.192576576348029
# Frequency: 50 Hz, Value: 43.026509309853715
# Frequency: 300 Hz, Value: 0.8323665355226985
# Frequency: 50 Hz, Value: 11.881104120475738
# Frequency: 300 Hz, Value: 0.07366838172741351
# Frequency: 50 Hz, Value: 3.6666591145023175
# Frequency: 300 Hz, Value: 0.06746719257019977
# Frequency: 50 Hz, Value: 1.1202384393646856
# Frequency: 300 Hz, Value: 0.03188488523969132
# Frequency: 50 Hz, Value: 0.24262248344414747
# Frequency: 300 Hz, Value: 0.0074942150282789255
# Frequency: 50 Hz, Value: 0.6130855585688143
# Frequency: 300 Hz, Value: 10.496439590776667
# Frequency: 50 Hz, Value: 0.0323059600272981
# Frequency: 300 Hz, Value: 0.006449623238556196
# Frequency: 50 Hz, Value: 0.004436431148437507
# Frequency: 300 Hz, Value: 0.003217463269597329
# Frequency: 50 Hz, Value: 0.0025484586788506506
# Frequency: 300 Hz, Value: 0.0007589819755974228
# Frequency: 50 Hz, Value: 0.0033162623370983197
# Frequency: 300 Hz, Value: 0.0004660247669722772
# Frequency: 50 Hz, Value: 13.716024110975015
# Frequency: 300 Hz, Value: 4.40748389112686
# Frequency: 50 Hz, Value: 122.17015149234197
# Frequency: 300 Hz, Value: 0.14139078638906
# Frequency: 50 Hz, Value: 31.579873939747387
# Frequency: 300 Hz, Value: 0.5515853636318159
# Frequency: 50 Hz, Value: 9.43393601586214
# Frequency: 300 Hz, Value: 0.2714555922834098
# Frequency: 50 Hz, Value: 2.8228561165257204
# Frequency: 300 Hz, Value: 0.08858162554442871
# Frequency: 50 Hz, Value: 0.7571513341859607
# Frequency: 300 Hz, Value: 0.021400340858848024
# Frequency: 50 Hz, Value: 0.5562827610808224
# Frequency: 300 Hz, Value: 11.698336005392171
# Frequency: 50 Hz, Value: 0.07121533566147398
# Frequency: 300 Hz, Value: 1.206274030195335
# Frequency: 50 Hz, Value: 0.002903742035469291
# Frequency: 300 Hz, Value: 0.019828342475335218
# Frequency: 50 Hz, Value: 0.0022330023030946427
# Frequency: 300 Hz, Value: 0.0023998290538206667
# Frequency: 50 Hz, Value: 0.0009243975252057194
# Frequency: 300 Hz, Value: 0.0007166739014452169
# Frequency: 50 Hz, Value: 0.0014701077772162007
# Frequency: 300 Hz, Value: 0.00019100690177306482
# Frequency: 50 Hz, Value: 49.75523742271206
# Frequency: 300 Hz, Value: 3.9711403745864544
# Frequency: 50 Hz, Value: 88.09769402022907
# Frequency: 300 Hz, Value: 0.42383096052571595
# Frequency: 50 Hz, Value: 24.00144095621072
# Frequency: 300 Hz, Value: 0.792308658479238
# Frequency: 50 Hz, Value: 6.695922029738041
# Frequency: 300 Hz, Value: 0.19795333843903706
# Frequency: 50 Hz, Value: 1.916255616883043
# Frequency: 300 Hz, Value: 0.03112325394515609
# Frequency: 50 Hz, Value: 0.5058788843785608
# Frequency: 300 Hz, Value: 0.0031548217862455894
# Frequency: 50 Hz, Value: 0.5389571273785744
# Frequency: 300 Hz, Value: 10.500245392416325
# Frequency: 50 Hz, Value: 0.05129046112674992
# Frequency: 300 Hz, Value: 0.04426609153409281
# Frequency: 50 Hz, Value: 0.012847245155573837
# Frequency: 300 Hz, Value: 0.0022450215030723644
# Frequency: 50 Hz, Value: 0.0028399811974206806
# Frequency: 300 Hz, Value: 0.00038011579407332634
# Frequency: 50 Hz, Value: 0.0017969468874083471
# Frequency: 300 Hz, Value: 0.000581599363479205
# Frequency: 50 Hz, Value: 0.0001431984529931667
# Frequency: 300 Hz, Value: 0.0003203535755761899
# Frequency: 50 Hz, Value: 76.46436201090263
# Frequency: 300 Hz, Value: 4.123767985076335
# Frequency: 50 Hz, Value: 63.84246054644936
# Frequency: 300 Hz, Value: 1.6650733871470906
# Frequency: 50 Hz, Value: 16.030516189398867
# Frequency: 300 Hz, Value: 0.29091656136195737
# Frequency: 50 Hz, Value: 4.678549944898684
# Frequency: 300 Hz, Value: 0.0263195513918296
# Frequency: 50 Hz, Value: 1.4629018204234536
# Frequency: 300 Hz, Value: 0.026931693334202346
# Frequency: 50 Hz, Value: 0.3673872459492495
# Frequency: 300 Hz, Value: 0.010578653822126347
# Frequency: 50 Hz, Value: 0.5736040482187704
# Frequency: 300 Hz, Value: 10.522336293640333
# Frequency: 50 Hz, Value: 0.026898584975431745
# Frequency: 300 Hz, Value: 0.06438410711439968
# Frequency: 50 Hz, Value: 0.003592632194041064
# Frequency: 300 Hz, Value: 0.005714768923570216
# Frequency: 50 Hz, Value: 0.004497396636696107
# Frequency: 300 Hz, Value: 0.0008685701072192848
# Frequency: 50 Hz, Value: 0.0031968456780989405
# Frequency: 300 Hz, Value: 0.0006655300606254255
# Frequency: 50 Hz, Value: 0.0001499585640159389
# Frequency: 300 Hz, Value: 9.60407877345501e-05
# Frequency: 50 Hz, Value: 104.0662899579532
# Frequency: 300 Hz, Value: 4.342920881756062
# Frequency: 50 Hz, Value: 41.52225750113764
# Frequency: 300 Hz, Value: 0.2641499086610029
# Frequency: 50 Hz, Value: 12.107862098617485
# Frequency: 300 Hz, Value: 0.21571484089245516
# Frequency: 50 Hz, Value: 3.7380545444339264
# Frequency: 300 Hz, Value: 0.10343140228121804
# Frequency: 50 Hz, Value: 1.0891887241933944
# Frequency: 300 Hz, Value: 0.034172449084498895
# Frequency: 50 Hz, Value: 0.693705777959825
# Frequency: 300 Hz, Value: 1.6803798546020947
# Frequency: 50 Hz, Value: 1.16274504015275
# Frequency: 300 Hz, Value: 9.231481095741545
# Frequency: 50 Hz, Value: 0.007604402026536036
# Frequency: 300 Hz, Value: 0.023740787905246218
# Frequency: 50 Hz, Value: 0.0015838461998076171
# Frequency: 300 Hz, Value: 0.002723950592804163
# Frequency: 50 Hz, Value: 0.0029552031175439667
# Frequency: 300 Hz, Value: 0.0008472598500767769
# Frequency: 50 Hz, Value: 0.003389632948822553
# Frequency: 300 Hz, Value: 0.00042415546820557637
# Frequency: 50 Hz, Value: 12.527794585929655
# Frequency: 300 Hz, Value: 5.917110948681778
# Frequency: 50 Hz, Value: 120.82861664460978
# Frequency: 300 Hz, Value: 1.113134128209963
# Frequency: 50 Hz, Value: 32.16371092154977
# Frequency: 300 Hz, Value: 0.8977065114456428
# Frequency: 50 Hz, Value: 9.268427209797238
# Frequency: 300 Hz, Value: 0.29578561949631627
# Frequency: 50 Hz, Value: 2.6597087445813266
# Frequency: 300 Hz, Value: 0.07287656693414286
# Frequency: 50 Hz, Value: 0.7096294415130747
# Frequency: 300 Hz, Value: 0.01037361280052231
# Frequency: 50 Hz, Value: 0.696722370492723
# Frequency: 300 Hz, Value: 11.435711196947118
# Frequency: 50 Hz, Value: 0.13155406033327774
# Frequency: 300 Hz, Value: 0.9567629352560346
# Frequency: 50 Hz, Value: 0.007222733784342444
# Frequency: 300 Hz, Value: 0.013662026401341603
# Frequency: 50 Hz, Value: 0.0032056384603864905
# Frequency: 300 Hz, Value: 0.00267462468238853
# Frequency: 50 Hz, Value: 0.0009743115769932369
# Frequency: 300 Hz, Value: 0.0008423404964272315
# Frequency: 50 Hz, Value: 0.0012040646353459763
# Frequency: 300 Hz, Value: 0.00024069577131734772
# Frequency: 50 Hz, Value: 50.71632538995898
# Frequency: 300 Hz, Value: 4.8399548339662966
# Frequency: 50 Hz, Value: 88.13216537385355
# Frequency: 300 Hz, Value: 0.699524634270273
# Frequency: 50 Hz, Value: 22.554579021570177
# Frequency: 300 Hz, Value: 0.6584641369434212
# Frequency: 50 Hz, Value: 6.259455436435143
# Frequency: 300 Hz, Value: 0.10757288440389207
# Frequency: 50 Hz, Value: 1.8749313098516889
# Frequency: 300 Hz, Value: 0.011458905510157245
# Frequency: 50 Hz, Value: 0.5156764510712115
# Frequency: 300 Hz, Value: 0.011115711521035026
# Frequency: 50 Hz, Value: 0.6421480752010583
# Frequency: 300 Hz, Value: 10.416210693020897
# Frequency: 50 Hz, Value: 0.06639438204855548
# Frequency: 300 Hz, Value: 0.07884674018531715
# Frequency: 50 Hz, Value: 0.003615629761020084
# Frequency: 300 Hz, Value: 0.004979383902282865
# Frequency: 50 Hz, Value: 0.0034843573086497247
# Frequency: 300 Hz, Value: 0.0006262655468564108
# Frequency: 50 Hz, Value: 0.0022887585500886384
# Frequency: 300 Hz, Value: 0.0001818293413811914
# Frequency: 50 Hz, Value: 0.00021964361228012143
# Frequency: 300 Hz, Value: 0.0003147105354207885
# Frequency: 50 Hz, Value: 80.43952173750077
# Frequency: 300 Hz, Value: 5.175767902747873
# Frequency: 50 Hz, Value: 59.91398511982537
# Frequency: 300 Hz, Value: 1.2842441131575306
# Frequency: 50 Hz, Value: 15.60960672873969
# Frequency: 300 Hz, Value: 0.0961933172611644
# Frequency: 50 Hz, Value: 4.768509765979186
# Frequency: 300 Hz, Value: 0.08923490380337823
# Frequency: 50 Hz, Value: 1.4834897557885351
# Frequency: 300 Hz, Value: 0.041866528677399234
# Frequency: 50 Hz, Value: 0.3530337933010606
# Frequency: 300 Hz, Value: 0.011704265021649448
# Frequency: 50 Hz, Value: 0.5233389051614525
# Frequency: 300 Hz, Value: 10.501641591326829
# Frequency: 50 Hz, Value: 0.07937193634268461
# Frequency: 300 Hz, Value: 0.02957155706802672
# Frequency: 50 Hz, Value: 0.0031859428077165007
# Frequency: 300 Hz, Value: 0.004333901286768092
# Frequency: 50 Hz, Value: 0.002691963015021292
# Frequency: 300 Hz, Value: 0.0014072426752697858
# Frequency: 50 Hz, Value: 0.003173808445169698
# Frequency: 300 Hz, Value: 0.0005590958843368479
# Frequency: 50 Hz, Value: 0.00018778110291275081
# Frequency: 300 Hz, Value: 3.2820324938014024e-05
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[1], line 70
#      65 data = wav_file.readframes(CHUNK)
#      67 while len(data) > 0:
#      68
#      69     # convert data to integers, make np array, then offset it by 128
# ---> 70     data_int = np.array(struct.unpack(f"{2 * CHUNK}h", data), dtype=np.int16) + 128
#      72     # compute FFT
#      73     yf = fft(data_int)
#
# error: unpack requires a buffer of 16384 bytes
